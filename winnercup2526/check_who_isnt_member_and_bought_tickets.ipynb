# %%
import pandas as pd
import numpy as np

# %%
seasontickets = pd.read_csv('seasontickets.csv')
seasontickets = seasontickets[seasontickets['Status'] == 'Active']
seasontickets['User Id'] = seasontickets['User Id'].astype(int)
seasontickets = seasontickets.drop_duplicates(subset=['User Id'])

tickets = pd.read_csv('games.csv')
tickets = tickets.dropna(subset=['User Id']) # without cashier tickets
tickets['User Id'] = tickets['User Id'].astype(int)
tickets = tickets[tickets['Status'] == 'Active']

# %%
print('seasontickets shape:', seasontickets.shape)
print('tickets shape:', tickets.shape)
# Out:
# seasontickets shape: (3421, 54)
# tickets shape: (4111, 54)

# %%
without_members = tickets[~tickets['User Id'].isin(seasontickets['User Id'])]
print('Tickets bought by non-members:', without_members.shape[0])
without_members
# Out:
# Tickets bought by non-members: 2305
#       Product Id                                      Product  Status  \
# 8           4270  גביע ווינר שלב הבתים #1: מכבי ראשון לציון 🏠  Active
# 57          4270  גביע ווינר שלב הבתים #1: מכבי ראשון לציון 🏠  Active
# 60          4270  גביע ווינר שלב הבתים #1: מכבי ראשון לציון 🏠  Active
# 61          4270  גביע ווינר שלב הבתים #1: מכבי ראשון לציון 🏠  Active
# 62          4270  גביע ווינר שלב הבתים #1: מכבי ראשון לציון 🏠  Active
# ...          ...                                          ...     ...
# 4572        4633             חצי גמר גביע ווינר: מכבי תל אביב  Active
# 4573        4633             חצי גמר גביע ווינר: מכבי תל אביב  Active
# 4574        4633             חצי גמר גביע ווינר: מכבי תל אביב  Active
# 4575        4633             חצי גמר גביע ווינר: מכבי תל אביב  Active
# 4576        4633             חצי גמר גביע ווינר: מכבי תל אביב  Active
#
#            Id                  Fan / Company  User Id assign using  ID number  \
# 8     3449096  עידן מזרחי - מכבי ראשון לציון  1429510               300606043
# 57    3448919                      אורטל לוי  1435228               066406752
# 60    3448904                    Marc Miller  1435227               A23058789
# 61    3448901                  עילאי גולדברג    29060               222745820
# 62    3448896                       שרון נדב  1435226               036107399
# ...       ...                            ...      ...                     ...
# 4572  3463102                      גיא גוטמן  1390682               031506249
# 4573  3463108                  אלעזר בנג'מין    46092                33301383
# 4574  3463107                      גיא גוטמן  1390682               031506249
# 4575  3463101                      גיא גוטמן  1390682               031506249
# 4576  3463103                      גיא גוטמן  1390682               031506249
#
#      First name                 Last name                        Email  ...  \
# 8          עידן  מזרחי - מכבי ראשון לציון   Idan.mizrachi.99@gmail.com  ...
# 57        אורטל                       לוי           ortalm18@gmail.com  ...
# 60         Marc                    Miller   mmiller@tocohillrealty.com  ...
# 61        עילאי                   גולדברג           yaelgold@gmail.com  ...
# 62         שרון                       נדב     sharon_nadav@walla.co.il  ...
# ...         ...                       ...                          ...  ...
# 4572        גיא                     גוטמן           guy.igfs@gmail.com  ...
# 4573      אלעזר                   בנג'מין  elazar.m.benjamin@gmail.com  ...
# 4574        גיא                     גוטמן           guy.igfs@gmail.com  ...
# 4575        גיא                     גוטמן           guy.igfs@gmail.com  ...
# 4576        גיא                     גוטמן           guy.igfs@gmail.com  ...
#
#       Delivery type Ticket Note Transaction Note           Role  \
# 8     Online ticket         NaN              NaN  Administrator
# 57    Online ticket         NaN              NaN           User
# 60    Online ticket         NaN              NaN           User
# 61    Online ticket         NaN              NaN           User
# 62    Online ticket         NaN              NaN           User
# ...             ...         ...              ...            ...
# 4572  Online ticket         NaN              NaN  Administrator
# 4573  Online ticket         NaN              NaN  Administrator
# 4574  Online ticket         NaN              NaN  Administrator
# 4575  Online ticket         NaN              NaN  Administrator
# 4576  Online ticket         NaN              NaN  Administrator
#
#       ReturnRequestStatus Voucher number   Voucher name Voucher value  \
# 8                     NaN            NaN            NaN           NaN
# 57                    NaN            NaN            NaN           NaN
# 60                    NaN    יאללה אפרתה  יאללה בתי ספר           NaN
# 61                    NaN            NaN            NaN           NaN
# 62                    NaN   יאללה גוננים  יאללה בתי ספר           NaN
# ...                   ...            ...            ...           ...
# 4572                  NaN            NaN            NaN           NaN
# 4573                  NaN            NaN            NaN           NaN
# 4574                  NaN            NaN            NaN           NaN
# 4575                  NaN            NaN            NaN           NaN
# 4576                  NaN            NaN            NaN           NaN
#
#      BindingTime Unnamed: 53
# 8            NaN         NaN
# 57           NaN         NaN
# 60           NaN         NaN
# 61           NaN         NaN
# 62           NaN         NaN
# ...          ...         ...
# 4572         NaN         NaN
# 4573         NaN         NaN
# 4574         NaN         NaN
# 4575         NaN         NaN
# 4576         NaN         NaN
#
# [2305 rows x 54 columns]

# %%
# --- helpers ---
def concat_unique(s):
    s = s.dropna().astype(str).str.strip()
    if s.empty:
        return np.nan
    return ', '.join(pd.unique(s))

def first_nonnull(s):
    s = s.dropna()
    return s.iloc[0] if not s.empty else np.nan

def most_common_or_join(s):
    s = s.dropna().astype(str).str.strip()
    if s.empty:
        return np.nan
    m = s.mode()
    # if one clear mode, use it; otherwise join uniques
    return m.iloc[0] if len(m) == 1 else ', '.join(pd.unique(s))

# --- tidy up & casting ---
df = without_members.copy()

# normalize name whitespace to avoid duplicate keys
df['Fan / Company'] = df['Fan / Company'].astype(str).str.strip()

# make sure Price is numeric
# (keeps digits and dot; strips currency symbols, commas, spaces)
df['Price'] = (
    df['Price']
      .astype(str)
      .str.replace(r'[^0-9.\-]', '', regex=True)
      .replace({'': np.nan, '-': np.nan})
      .astype(float)
)

# ensure Birth date is datetime
df['Birth date'] = pd.to_datetime(df['Birth date'], errors='coerce')

# --- 1) one line per (person, product) ---
per_product = (
    df.groupby(['Fan / Company', 'User Id', 'Product'], dropna=False)
      .agg(
          tickets_bought = ('Product', 'size'),
          total_price    = ('Price', 'sum'),
          ticket_price_types = ('Ticket price types', concat_unique),
          voucher_numbers    = ('Voucher number', concat_unique),
          voucher_names      = ('Voucher name', concat_unique),
          phone              = ('Phone', most_common_or_join),
          email              = ('Email', most_common_or_join),
          birth_date         = ('Birth date', first_nonnull)
      )
      .reset_index()
)

# --- 2) one line per person ---
person_summary = (
    df.groupby(['Fan / Company', 'User Id'], dropna=False)
      .agg(
          phone            = ('Phone', most_common_or_join),
          email            = ('Email', most_common_or_join),
          total_tickets    = ('Product', 'size'),
          product_list     = ('Product', concat_unique),
          distinct_products= ('Product', 'nunique'),
          total_price      = ('Price', 'sum'),
          ticket_price_types = ('Ticket price types', concat_unique),
          voucher_numbers    = ('Voucher number', concat_unique),
          voucher_names      = ('Voucher name', concat_unique),
          birth_date         = ('Birth date', first_nonnull)
      )
      .reset_index()
)

today = pd.Timestamp.today().normalize()
bd = person_summary['birth_date']

# has the person already had their birthday this year?
has_had_bday = (
    (bd.dt.month < today.month) |
    ((bd.dt.month == today.month) & (bd.dt.day <= today.day))
)

age = (today.year - bd.dt.year) - (~has_had_bday).astype(int)

# keep NaN where birth_date is missing
person_summary['age'] = age.where(bd.notna())

# optional: order columns nicely
person_summary = person_summary[
    ['Fan / Company', 'User Id', 'phone', 'email',
     'total_tickets', 'distinct_products', 'product_list',
     'total_price', 'ticket_price_types', 'voucher_numbers', 'voucher_names', 'age']
]

person_summary
# Out:
#            Fan / Company  User Id       phone                       email  \
# 0           Adam Berrous  1420654  0552864391       adamberrous@gmail.com
# 1    Alejandra Rosenberg  1435692  0515690960  alerosenberg81@hotmail.com
# 2         Anthony   Lamb  1435129         NaN                         NaN
# 3            Asaf Ataria  1424949  0503744476       asaf.ataria@gmail.com
# 4           Austin Wiley  1349202         NaN    Austin.wiley50@gmail.com
# ..                   ...      ...         ...                         ...
# 995             תמר בנאי  1404140         NaN                         NaN
# 996         תמר זקנשטיין  1435263  0524492550          tamarst4@gmail.com
# 997             תמר שגיב  1434826         NaN                         NaN
# 998             תמר שכטר  1343401         NaN                         NaN
# 999         ‫בניה כספי‬‎  1421903  0544487979            cbnaya@gmail.com
#
#      total_tickets  distinct_products  \
# 0                1                  1
# 1                4                  1
# 2                2                  1
# 3                1                  1
# 4                1                  1
# ..             ...                ...
# 995              1                  1
# 996              6                  1
# 997              1                  1
# 998              1                  1
# 999              1                  1
#
#                                       product_list  total_price  \
# 0      גביע ווינר שלב הבתים #1: מכבי ראשון לציון 🏠         50.0
# 1    גביע ווינר שלב הבתים #2: מכבי עירוני רמת גן 🏠        440.0
# 2      גביע ווינר שלב הבתים #1: מכבי ראשון לציון 🏠          0.0
# 3                 חצי גמר גביע ווינר: מכבי תל אביב         75.0
# 4                 חצי גמר גביע ווינר: מכבי תל אביב          0.0
# ..                                             ...          ...
# 995               חצי גמר גביע ווינר: מכבי תל אביב         75.0
# 996  גביע ווינר שלב הבתים #2: מכבי עירוני רמת גן 🏠          0.0
# 997  גביע ווינר שלב הבתים #2: מכבי עירוני רמת גן 🏠          0.0
# 998  גביע ווינר שלב הבתים #2: מכבי עירוני רמת גן 🏠          0.0
# 999    גביע ווינר שלב הבתים #1: מכבי ראשון לציון 🏠          0.0
#
#     ticket_price_types voucher_numbers  voucher_names   age
# 0                Child             NaN            NaN  12.0
# 1                Adult             NaN            NaN  44.0
# 2        Complementary             NaN            NaN   NaN
# 3                Adult             NaN            NaN  17.0
# 4        Complementary             NaN            NaN   NaN
# ..                 ...             ...            ...   ...
# 995              Adult             NaN            NaN  12.0
# 996              Adult   יאללה יפה נוף  יאללה בתי ספר  39.0
# 997              Adult     יאללה אפרתה  יאללה בתי ספר  16.0
# 998              Child    יאללה גוננים  יאללה בתי ספר  10.0
# 999              Adult    יאללה גוננים  יאללה בתי ספר  43.0
#
# [1000 rows x 12 columns]

# %%
person_summary.to_excel('winnercup_tickets_non_members.xlsx', index=False)
