# %%
import pandas as pd
import numpy as np

# %%
products = pd.read_csv('products.csv')

# %%
# Rename columns
products = products.rename(columns={
    'Product Id': 'ProductId',
    'Product': 'ProductName',
    'Date.1': 'ProductDate'
})

# Add missing columns
new_columns = ['Season ID', 'StadiumId', 'ProductType']

for col in new_columns:
    if col not in products.columns:
        products[col] = None

# Reorder columns
desired_columns = ['ProductId', 'Season ID', 'ProductName', 'ProductType', 'ProductDate', 'StadiumId']
for col in desired_columns:
    if col not in products.columns:
        products[col] = None
products = products[desired_columns]

# Set default values
products['Season ID'] = 24
products['ProductType'] = 'Merchndise'

products = products.drop_duplicates(subset='ProductName')

# New row as a dictionary
new_row = {
    'ProductId': 62,
    'Season ID': 24,
    'ProductName': 'מנוי לעונת 2024/2025',
    'ProductType': 'SeasonTicket',
    'ProductDate': '2024-06-17',
    'StadiumId': 1
}

# Convert the dict to a DataFrame
new_row_df = pd.DataFrame([new_row])

# Concatenate
products = pd.concat([products, new_row_df], ignore_index=True)

products
# Out:
#     ProductId  Season ID                                       ProductName  \
# 0        1063         24                 פרסום: דף העסקים של הפועל 2025/26
# 1         139         24                                 Payment Gate Test
# 2         271         24        מנוי הסעות למשחקי הבית - מחוץ לחומות 24/25
# 3         337         24                         פרסום: דף העסקים של הפועל
# 4         403         24                               פרסום: שקופית ג'מבו
# 5         404         24                          פרסום: ג'מבו סטריפ תחתון
# 6         436         24                                   פרסום: לד תחתון
# 7         469         24                                   פרסום: לד עליון
# 8         471         24                                פרסום: לד תחתון צד
# 9         476         24                             פרסום: מסך לד בסיס סל
# 10        477         24                            פרסום: לד סל מסך עליון
# 11        483         24                            פרסום: גב ראיונות ליגה
# 12        502         24                                        מנוי קהילה
# 13        634         24                               חוגגים: ברכה בג'מבו
# 14        799         24                   הסעות למשחקי הבית - מחוץ לחומות
# 15        832         24         הסעות למשחק הבית בחולון - מול מכבי רמת גן
# 16        865         24        חבילה לסופיה 13-15 לינואר: צדויטה אולימפיה
# 17        997         24  הרמת כוסית לפסח - הקהילה העסקית של הפועל ירושלים
# 18         62         24                              מנוי לעונת 2024/2025
#
#      ProductType ProductDate StadiumId
# 0     Merchndise  2025-06-10      None
# 1     Merchndise  2024-07-18      None
# 2     Merchndise  2024-12-03      None
# 3     Merchndise  2025-03-19      None
# 4     Merchndise  2025-02-25      None
# 5     Merchndise  2024-10-07      None
# 6     Merchndise  2025-02-25      None
# 7     Merchndise  2025-02-25      None
# 8     Merchndise  2024-12-23      None
# 9     Merchndise  2025-05-20      None
# 10    Merchndise  2024-12-23      None
# 11    Merchndise  2024-09-30      None
# 12    Merchndise  2024-11-20      None
# 13    Merchndise  2025-05-25      None
# 14    Merchndise  2024-12-19      None
# 15    Merchndise  2025-01-05      None
# 16    Merchndise  2025-01-13      None
# 17    Merchndise  2025-04-08      None
# 18  SeasonTicket  2024-06-17         1

# %%
tickets = pd.read_excel('tickets2425.xlsx')

# %%
# 1. Extract only relevant columns from tickets
match_info = tickets[['Product ID' ,'Asset Name', 'Season ID', 'Product Date']]

# 2. Keep only the first occurrence per unique 'Asset Name'
match_info = match_info.drop_duplicates(subset='Asset Name')

# 3. Rename to match products column names
match_info = match_info.rename(columns={
    'Asset Name': 'ProductName',
    'Product Date': 'ProductDate',
    'Product ID': 'ProductId'
})

# 4. Add fixed values
match_info['ProductType'] = 'Match'
match_info['StadiumId'] = 1

# 6. Reorder columns to match `products` table
# Ensure this order matches the actual structure of your products DataFrame
match_info = match_info[['ProductId', 'Season ID', 'ProductName', 'ProductType', 'ProductDate', 'StadiumId']]

# 7. Concatenate into products
products = pd.concat([products, match_info], ignore_index=True)

products
# Out:
#    ProductId  Season ID                                 ProductName  \
# 0       1063         24           פרסום: דף העסקים של הפועל 2025/26
# 1        139         24                           Payment Gate Test
# 2        271         24  מנוי הסעות למשחקי הבית - מחוץ לחומות 24/25
# 3        337         24                   פרסום: דף העסקים של הפועל
# 4        403         24                         פרסום: שקופית ג'מבו
# ..       ...        ...                                         ...
# 82      4171         24       גמר ליגת ווינר משחק 1: מכבי תל אביב 🚗
# 83      4172         24       גמר ליגת ווינר משחק 2: מכבי תל אביב 🏠
# 84      4204         24          חניה חיצונית VIP מכבי תל אביב 12.6
# 85      4205         24              חניה פנימית  מכבי תל אביב 12.6
# 86      4237         24       גמר ליגת ווינר משחק 3: מכבי תל אביב 🚗
#
#    ProductType ProductDate StadiumId
# 0   Merchndise  2025-06-10      None
# 1   Merchndise  2024-07-18      None
# 2   Merchndise  2024-12-03      None
# 3   Merchndise  2025-03-19      None
# 4   Merchndise  2025-02-25      None
# ..         ...         ...       ...
# 82       Match  2025-06-10         1
# 83       Match  2025-06-15         1
# 84       Match  2025-06-12         1
# 85       Match  2025-06-12         1
# 86       Match  2025-06-13         1
#
# [87 rows x 6 columns]

# %%
vouchers = pd.read_csv('vouchers.csv')
# Out:
# /var/folders/nt/lqq9984n7p3fpfvd92swmw280000gn/T/ipykernel_5273/3373123004.py:1: DtypeWarning: Columns (29,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   vouchers = pd.read_csv('vouchers.csv')

# %%
# 1. Extract only relevant columns from tickets
vouchers_info = vouchers[['Product Id' ,'Product', 'Date.1']]

# 2. Keep only the first occurrence per unique 'Asset Name'
vouchers_info = vouchers_info.drop_duplicates(subset='Product')

# 3. Rename to match products column names
vouchers_info = vouchers_info.rename(columns={
    'Product': 'ProductName',
    'Date.1': 'ProductDate',
    'Product Id': 'ProductId'
})

vouchers_info['ProductDate'] = pd.to_datetime(vouchers_info['ProductDate'], dayfirst=True).dt.date

# 4. Add fixed values
vouchers_info['ProductType'] = 'Voucher'
vouchers_info['StadiumId'] = 1
vouchers_info['Season ID'] = 24

# 6. Reorder columns to match `products` table
# Ensure this order matches the actual structure of your products DataFrame
vouchers_info = vouchers_info[['ProductId', 'Season ID', 'ProductName', 'ProductType', 'ProductDate', 'StadiumId']]

# 7. Concatenate into products
products = pd.concat([products, vouchers_info], ignore_index=True)

products
# Out:
#     ProductId  Season ID                                 ProductName  \
# 0        1063         24           פרסום: דף העסקים של הפועל 2025/26
# 1         139         24                           Payment Gate Test
# 2         271         24  מנוי הסעות למשחקי הבית - מחוץ לחומות 24/25
# 3         337         24                   פרסום: דף העסקים של הפועל
# 4         403         24                         פרסום: שקופית ג'מבו
# ..        ...        ...                                         ...
# 223       863         24                                         50%
# 224       895         24           המרת שינוי לתעריף מבוגר קטגוריה C
# 225       928         24                                  one family
# 226       994         24                                       שמביק
# 227         9         24                                Virtual Card
#
#     ProductType ProductDate StadiumId
# 0    Merchndise  2025-06-10      None
# 1    Merchndise  2024-07-18      None
# 2    Merchndise  2024-12-03      None
# 3    Merchndise  2025-03-19      None
# 4    Merchndise  2025-02-25      None
# ..          ...         ...       ...
# 223     Voucher  2024-10-30         1
# 224     Voucher  2024-07-21         1
# 225     Voucher  2024-09-19         1
# 226     Voucher  2024-08-01         1
# 227     Voucher  2025-06-19         1
#
# [228 rows x 6 columns]

# %%
products.to_excel('products2425.xlsx')
